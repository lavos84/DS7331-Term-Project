# %% [markdown]
# # - DS 7331 Term Project
#
# The data we chose came from Kaggle.com and pertains to owned and leased properties in New York City.  The data is available at https://www.kaggle.com/new-york-city/ny-city-owned-and-leased-property and is updated quarterly.  It contains 55951 records and 74 variables consisting of continuous, discrete, and categorical data alike.  Missing values are also present and will have to be addressed as appropriate.

# %% [markdown]
# Below, a description of each variable is provided for convenience, but can be found using the link above.
#
# <br>**Borough**  The borough that the tax lot is located in
# <br>**Map Atlas**  The map on which the property appears in the most recent atlas of the city property
# <br>**Block**  The tax block that the tax lot is located in
# <br>**Lot**  The number of the tax lot
# <br>**Address**  An address for the tax lot
# <br>**Parcel Name**  General Property name
# <br>**Agency**  The city agency to which the property is assigned
# <br>**Current Uses**  Sufficient information to determine the property’s current use or to determine that it has no current use
# <br>**Total Area**  Total area, expressed in square feet and rounded to the nearest integer
# <br>**Open Petroleum Spill**  Whether the property contains the presence of an open petroleum spill
# <br>**Govt Clean-Up Program**  Whether the property is enrolled in a government cleanup, and if so, the name of such program
# <br>**Structure Completed**  The year construction of the structure(s) was completed and whether such year is an estimate, where applicable
# <br>**Number Structures**  The number of structures
# <br>**Total Gross Area Structures**  Total gross area of all structures expressed in square feet rounded to the nearest integer, where applicable
# <br>**Ratio Building to Floor Area**  Ratio of building floor area to the area of the property, where applicable
# <br>**Allowable Building to Floor Area**  Allowable ratio of building floor area to the area of the property, where applicable
# <br>**Land Use Category**  A code for the tax lot's land use category, modified for display of parks, New York City Department of Parks and Recreation properties and New York State Office of Parks, Recreation and Historic Preservation properties in the appropriate category on land
# <br>**Community Board**  The community district (CD) or joint interest area (JIA) that the tax lot is located in, or partially located in
# <br>**Census Tract**  The 2010 census tract that the tax lot is located in
# <br>**Census Block**  The 2010 census block that the tax lot is located in
# <br>**School Dist**  The community school district that the tax lot is located in
# <br>**Council District**  The city council district that the tax lot is located in
# <br>**Postcode**  The zip code that the tax lot is located in
# <br>**Fire Comp**  The fire company that services the property
# <br>**Health Area**  The health area
# <br>**Health Ctr**  The health center district
# <br>**Police Prct**  The police precinct
# <br>**Major Use**  The major use of the structure or structures, where applicable
# <br>**Number of Easements**  The number of easements, where applicable
# <br>**Commercial Floor Area**  The exterior dimensions of the portion of the structure or structures allocated for commercial use, where applicable
# <br>**Residential Floor Area**  The exterior dimensions of the portion of the structure or structures allocated for residential use, where applicable
# <br>**Office Floor Area**  An estimate of the exterior dimensions of the portion of the structure(s) allocated for office use
# <br>**Retail Floor Area**  An estimate of the exterior dimensions of the portion of the structure(s) allocated for retail use
# <br>**Garage Floor Area**  An estimate of the exterior dimensions of the portion of the structure(s) allocated for garage use
# <br>**Storage Floor Area**  An estimate of the exterior dimensions of the portion of the structure(s) allocated for storage or loft purposes
# <br>**Factory Floor Area**  An estimate of the exterior dimensions of the portion of the structure(s) allocated for factory, warehouse or loft use
# <br>**Other Floor Area**  An estimate of the exterior dimensions of the portion of the structure(s) allocated for other than Residential, Office, Retail, Garage, Storage, Loft or Factory use
# <br>**Num Floors**  In the primary building on the tax lot, the number of full and partial stories starting from the ground floor
# <br>**Residential Units**  The sum of residential units in all buildings on the tax lot
# <br>**Residential and Non-Residential Units**  The sum of residential and non-residential units in all structures, where applicable
# <br>**Lot Front**  The frontage, measured in feet
# <br>**Lot Depth**  The depth, measured in feet
# <br>**Bldg Front**  The frontage along the street, measured in feet
# <br>**Bldg Depth**  The depth of the structure or structures, which is the effective perpendicular distance, measured in feet, where applicable
# <br>**Proximity Code**  Whether the structure or structures are detached, semi-detached or attached to neighboring structures, where applicable
# <br>**Irr Lot Code**  Whether the property is irregularly shaped
# <br>**Lot Type Code**  The location relative to another lot or water, expressed as mixed or unknown, block assemblage, waterfront, corner, through, inside, interior, island, alley, or submerged land
# <br>**Bsmt Code**  A code describing the basement
# <br>**Assess Land**  The actual assessed land value for Fiscal Year 2013
# <br>**Exempt Land**  The actual exempt land value, which is determined differently for each exemption program, is the dollar amount related to that portion of the tax lot that has received an exemption or abatement for Fiscal Year 2013
# <br>**Exempt Tot**  The actual exempt total value, which is determined differently for each exemption program, is the dollar amount related to that portion of the tax lot that has received an exemption or abatement for Fiscal Year 2013
# <br>**Year Alter 1**  If a building has only been altered once, this is the date of the alteration
# <br>**Year Alter 2**  If a building has been altered more than once, this is the year of the most recent alteration
# <br>**His Dist**  The name of the Historic District as designated by the New York City Landmarks Preservation Commission
# <br>**Landmark**  The name of an individual landmark, landmark site (e.g. Richmondtown Restoration), or an interior landmark, as designated by the New York City Landmarks Preservation Commission
# <br>**Condominium Number**  The condominium number assigned to the complex, where applicable
# <br>**Coordinates**  The coordinate of the XY coordinate pair that depicts the property’s approximate location as expressed in the New York-Long Island State Plane coordination system
# <br>**E-Designation Number**  The e-designation number associated with the property, where applicable
# <br>**Industrial Business Zone**  Whether the property is located in an industrial business zone
# <br>**Zone Dist 1**  The primary zoning classification of the property
# <br>**Zone Dist 2**  The zoning designation occupying the second greatest percentage of the property’s area, where applicable
# <br>**Overlay 1**  The primary commercial overlay assigned to the property, where applicable
# <br>**Overlay 2**  The commercial overlay occupying the second greatest percentage of the property’s area, where applicable
# <br>**SP Dist 1**  The special purpose district assigned to the tax lot
# <br>**SP Dist 2**  The special purpose district assigned to the tax lot
# <br>**Potential Urban Ag**  Whether the land is suitable for urban agriculture (for description, click “About” then “Attachments”)
# <br>**Contact**  Agency contact information, including name, telephone number and email address
# <br>**EDC % Occupied**  For each property assigned to the economic development corporation, such list shall include the percentage of usable space actually occupied by a tenant or tenants
# <br>**Pluto Version**  The Version Number related to the release of PLUTO
# <br>**Latitude**
# <br>**Longitude**
# <br>**BIN**  Building Identification Numbers (BINs) that are assigned to every known building in the city
# <br>**NTA**  Neighborhood Tabulation Areas are aggregations of census tracts that are subsets of New York City's 55 Public Use Microdata Areas (PUMAs)

# %% [markdown]
# # - Lab 1: Visualization and Data Preprocessing
#
# For this portion of the assignment, we must first read in the data.  In order to import it however, we will have to assign the appropriate data types to each feature included in the data, and define methods to handle missing values.  Once the data is imported, this will not only allow us to perform basic summary statistics for each feature, but also enable us to create other visualizations in order to gain a better understanding of the data.

# %%
# Import the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Assign data types and read in the data

# %%
# The data set contains a variety of data types.  It is best to specify them before importing.
datatypes = {"Borough": "category", 
             "Map Atlas": "category", 
             "Block": "int", "Lot": "int", 
             "Address": "str", "Parcel Name": "str",
             "Agency": "category", 
             "Current Uses": "str", 
             "Total Area": "int", 
             "Open Petroleum Spill": "category",
             "Govt Clean-Up Program": "category", 
             "Structure Completed": "float", 
             "Number Structures": "int",
             "Total Gross Area Structures": "int", 
             "Ratio Building to Floor Area": "float", 
             "Allowable Building to Floor": "int",
             "Land Use Category": "category", 
             "Community Board": "category", 
             "Census Tract": "float", 
             "Census Block": "category",
             "School Dist": "category", 
             "Council District": "category", 
             "Postcode": "category", 
             "Fire Comp": "category",
             "Health Area": "category", 
             "Health Ctr": "category", 
             "Police Prct": "category",
             "Major Use": "category",
             "Number of Easements": "int", 
             "Commercial Floor Area": "int", 
             "Residential Floor Area": "int",
             "Office Floor Area": "int", 
             "Retail Floor Area": "int", 
             "Garage Floor Area": "int", 
             "Storage Floor Area": "int",
             "Factory Floor Area": "int", 
             "Other Floor Area": "int", 
             "Num Floors": "float", 
             "Residential Units": "int",
             "Residential and Non-Residential Units": "int", 
             "Lot Front": "float", "Lot Depth": "float", 
             "Bldg Front": "float",
             "Bldg Depth": "float", 
             "Proximity Code": "category", 
             "Irr Lot Code": "str", 
             "Lot Type Code": "category",
             "Bsmt Code": "category", 
             "Assess Land": "float", 
             "Exempt Land": "float", 
             "Exempt Tot": "float", 
             "Year Alter 1": "int",
             "Year Alter 2": "int", 
             "His Dist": "category", 
             "Landmark": "str", 
             "Condominium Number": "int", 
             "Coordinates": "str",
             "E-Designation Number": "category", 
             "Industrial Business Zone": "category", 
             "Zone Dist": "category",
             "Zone Dist 2": "category", 
             "Overlay 1": "category", 
             "Overlay 2": "category", 
             "SP Dist 1": "category",
             "SP Dist 2": "category", 
             "Potential Urban Ag": "category", 
             "Contact": "str", 
             "EDC % Occupied": "float",
             "Pluto Version": "category", 
             "Latitude": "float", 
             "Longitude": "float", 
             "BIN": "str", 
             "NTA": "category"}
# Similarly, each column will have to have a different method of handling missing values.
nan = np.nan
nas = {"Borough": "", 
       "Map Atlas": "", 
       "Block": nan, 
       "Lot": nan, 
       "Address": "", 
       "Parcel Name": "", 
       "Agency": "", 
       "Current Uses": "",
       "Total Area": nan, 
       "Open Petroleum Spill": "", 
       "Govt Clean-Up Program": "", 
       "Structure Completed": nan,
       "Number Structures": nan, 
       "Total Gross Area Structures": nan, 
       "Ratio Building to Floor Area": nan,
       "Allowable Building to Floor": nan, 
       "Land Use Category": "", 
       "Community Board": "", 
       "Census Tract": nan,
       "Census Block": "", 
       "School Dist": "", 
       "Council District": "",
       "Postcode": "", 
       "Fire Comp": "", 
       "Health Area": "",
       "Health Ctr": "", 
       "Police Prct": "", 
       "Major Use": "", 
       "Number of Easements": nan, 
       "Commercial Floor Area": nan,
       "Residential Floor Area": nan, 
       "Office Floor Area": nan, 
       "Retail Floor Area": nan, 
       "Garage Floor Area": nan,
       "Storage Floor Area": nan, 
       "Factory Floor Area": nan, 
       "Other Floor Area": nan, 
       "Num Floors": nan,
       "Residential Units": nan, 
       "Residential and Non-Residential Units": nan, 
       "Lot Front": nan, "Lot Depth": nan,
       "Bldg Front": nan, "Bldg Depth": nan, 
       "Proximity Code": "", 
       "Irr Lot Code": "", 
       "Lot Type Code": "", 
       "Bsmt Code": "",
       "Assess Land": nan, 
       "Exempt Land": nan, 
       "Exempt Tot": nan, 
       "Year Alter 1": nan, 
       "Year Alter 2": nan, 
       "His Dist": "",
       "Landmark": "", 
       "Condominium Number": nan, 
       "Coordinates": "", 
       "E-Designation Number": "", 
       "Industrial Business Zone": "",
       "Zone Dist": "", 
       "Zone Dist 2": "", 
       "Overlay 1": "", 
       "Overlay 2": "", 
       "SP Dist 1": "", 
       "SP Dist 2": "",
       "Potential Urban Ag": "", 
       "Contact": "", 
       "EDC % Occupied": nan, 
       "Pluto Version": "", 
       "Latitude": nan, 
       "Longitude": nan,
       "BIN": "", 
       "NTA": ""}
# Read in the data.  I'm using an absolute path because I could not figure out how to use a relative path.
nyc = pd.read_csv("./Data/city-owned-and-leased-property-local-law-48-of-2011.csv",
                  dtype=datatypes, 
                  na_values=nas)
# Preview the data
nyc.head(50)
# Out:
#            Date Created Borough Map Atlas  Block  Lot               Address  \
# 0   2013-12-11T00:00:00       1         4      2    1       MARGINAL STREET
# 1   2013-12-11T00:00:00       1         4      2   23                PIER 6
# 2   2013-12-11T00:00:00       1         4      3    1          BATTERY PARK
# 3   2013-12-11T00:00:00       1         4      3    2    PETER MINUIT PLAZA
# 4   2013-12-11T00:00:00       1         4      3    3    PETER MINUIT PLAZA
# 5   2013-12-11T00:00:00       1         4      6    1       24 SOUTH STREET
# 6   2013-12-11T00:00:00       1         4     12   28      WHITEHALL STREET
# 7   2013-12-11T00:00:00       1         4     16    1      22 BATTERY PLACE
# 8   2013-12-11T00:00:00       1         4     16   12       MARGINAL STREET
# 9   2013-12-11T00:00:00       1         4     17   45        25 WEST STREET
# 10  2013-12-11T00:00:00       1         4     18  100   56 GREENWICH STREET
# 11  2013-12-11T00:00:00       1         4     19    8   65 GREENWICH STREET
# 12  2013-12-11T00:00:00       1         4     20   16           55 BROADWAY
# 13  2013-12-11T00:00:00       1         4     21    1           61 BROADWAY
# 14  2013-12-11T00:00:00       1         4     22   17           32 BROADWAY
# 15  2013-12-11T00:00:00       1         4     22   20           42 BROADWAY
# 16  2013-12-11T00:00:00       1         4     22   24           50 BROADWAY
# 17  2013-12-11T00:00:00       1         4     24    1       60 BROAD STREET
# 18  2013-12-11T00:00:00       1         4     28   28         BEAVER STREET
# 19  2013-12-11T00:00:00       1         4     29   19       75 PEARL STREET
# 20  2013-12-11T00:00:00       1         4     29   70       75 BROAD STREET
# 21  2013-12-11T00:00:00       1         4     29   73      44 BEAVER STREET
# 22  2013-12-11T00:00:00       1         4     34   37          100 OLD SLIP
# 23  2013-12-11T00:00:00       1         4     35    1       77 FRONT STREET
# 24  2013-12-11T00:00:00       1         4     36   12                PIER 9
# 25  2013-12-11T00:00:00       1         4     36   18   PIER11 SOUTH STREET
# 26  2013-12-11T00:00:00       1         4     36   25       13 SOUTH STREET
# 27  2013-12-11T00:00:00       1         4     36   30   PIER14 SOUTH STREET
# 28  2013-12-11T00:00:00       1         4     42   31        80 MAIDEN LANE
# 29  2013-12-11T00:00:00       2         1   2539  181    MAJ WM DEEGAN BLVD
# 30  2013-12-11T00:00:00       1         4     51   15      88 TRINITY PLACE
# 31  2013-12-11T00:00:00       1         4     52    1      96 TRINITY PLACE
# 32  2013-12-11T00:00:00       1         4     52   22  141 GREENWICH STREET
# 33  2013-12-11T00:00:00       1         4     64  106         LIBERTY PLACE
# 34  2013-12-11T00:00:00       1         4     67    1        66 JOHN STREET
# 35  2013-12-11T00:00:00       1         4     68    7        83 MAIDEN LANE
# 36  2013-12-11T00:00:00       1         4     70   32      180 WATER STREET
# 37  2013-12-11T00:00:00       1         4     73    2  PIER-15 SOUTH STREET
# 38  2013-12-11T00:00:00       1         4     73    8  PIER-16 SOUTH STREET
# 39  2013-12-11T00:00:00       1         4     73   10       95 SOUTH STREET
# 40  2013-12-11T00:00:00       1         4     73   11    95 MARGINAL STREET
# 41  2013-12-11T00:00:00       1         4     73   14          SOUTH STREET
# 42  2013-12-11T00:00:00       1         4     73   17               PIER 19
# 43  2013-12-11T00:00:00       1         4     73   28       MARGINAL STREET
# 44  2013-12-11T00:00:00       1         4     73   29       MARGINAL STREET
# 45  2013-12-11T00:00:00       1         4     74    1       89 SOUTH STREET
# 46  2013-12-11T00:00:00       1         4     74   20       2 FULTON STREET
# 47  2013-12-11T00:00:00       1         4     77    8    110 WILLIAM STREET
# 48  2013-12-11T00:00:00       1         4     92    5    161 WILLIAM STREET
# 49  2013-12-11T00:00:00       1         4     93    1      81 FULTON STREET
#
#                        Parcel Name             Agency  \
# 0    BATTERY MARITIME BLDG / FERRY          DOT, DSBS
# 1                           PIER 6               DSBS
# 2                     BATTERY PARK              PARKS
# 3    PETER MINUIT PLAZA/BATTERY PK              PARKS
# 4    PETER MINUIT PLAZA/BATTERY PK              PARKS
# 5           VIETNAM VETERANS PLAZA              PARKS
# 6               BOWLING GREEN PARK              PARKS
# 7          PIER A / MARINE UNIT #1               DSBS
# 8                BATTERY PARK CITY              PARKS
# 9   BROOKLYN BATTERY TUNNEL GARAGE               DCAS
# 10  B'KLYN BATTERY TUNNEL APPROACH               DCAS
# 11     PORTION OF BK BATTER TUNNEL              NYCTA
# 12                            NYPD               NYPD
# 13                             NaN                OCA
# 14                             NaN                DCA
# 15                     OFFICE BLDG   DCA, ELECT, HLTH
# 16                             NaN               EDUC
# 17                             NaN     DHS, PROB, TLC
# 18             HANOVER SQUARE PARK              PARKS
# 19                  COENTIES ALLEY                DOT
# 20                             NaN               EDUC
# 21        DEPARTMENT OF SANITATION              SANIT
# 22               NYC POLICE MUSEUM               CULT
# 23                   ENG 4, LAD 15               FIRE
# 24                   FORMER PIER 9               DSBS
# 25                         PIER 11               DSBS
# 26                         PIER 13               DSBS
# 27                         PIER 14               DSBS
# 28                DOI HEADQUARTERS          DOI, EDUC
# 29                MACOMBS DAM PARK              PARKS
# 30                             NaN               EDUC
# 31                             NaN               EDUC
# 32                  ENG 10, LAD 10               FIRE
# 33               VENTILATION SHAFT              NYCTA
# 34                     OFFICE BLDG  FINAN, ACS, DOITT
# 35                             NaN         BLDGS, DOI
# 36                HRA HEADQUARTERS                HRA
# 37                         PIER 15               DSBS
# 38                         PIER 16               DSBS
# 39  PIER 17 / SOUTH STREET SEAPORT               DSBS
# 40  FORMER FULTON FISH MARKET BLDG               DSBS
# 41   FORMER FULTON FIS MARKET BLDG               DSBS
# 42      FORMERLY PIERS 19, 20 & 21               DSBS
# 43     L.U.W. FOOT OF DOVER STREET               DSBS
# 44       L.U.W. UNDER BKLYN BRIDGE               DSBS
# 45   SOUTH ST SEAPORT/BURLING SLIP         HPD, PARKS
# 46   SOUTH ST SEAPORT/BURLING SLIP         HPD, PARKS
# 47                             NaN     EDC, DSBS, ACS
# 48                             NaN               DYCD
# 49                ACS HEADQUARTERS                ACS
#
#                                          Current Uses  Total Area  ...  \
# 0         FERRY TERMINAL, WATERFRONT PROPERTY, NO USE      209215  ...
# 1   NO USE, FINAL COMMITMNT-DISP, IN USE-TENANTED,...      510025  ...
# 2                                                PARK      945425  ...
# 3                                                PARK       39900  ...
# 4                                                PARK       33600  ...
# 5                                                PARK       35166  ...
# 6                                                PARK       22500  ...
# 7   FERRY TERMINAL, WATERFRONT PROPERTY, NO USE, F...       83100  ...
# 8         PARK, IN USE-TENANTED, SHORT-TERM AGREEMENT      237948  ...
# 9                                              GARAGE       67342  ...
# 10                               OTHER TRANS FACILITY      183456  ...
# 11                               OTHER TRANS FACILITY          71  ...
# 12                                        AGCY OFFICE       15722  ...
# 13                                        AGCY OFFICE       22197  ...
# 14                               AGCY EXECUTVE OFFICE        9372  ...
# 15                  AGCY EXECUTVE OFFICE, AGCY OFFICE       21490  ...
# 16                                      PUBLIC SCHOOL       13323  ...
# 17       OFFICE, AGCY EXECUTVE OFFICE, BOROUGH OFFICE       44757  ...
# 18                                               PARK        5075  ...
# 19                                       ROAD/HIGHWAY        2048  ...
# 20                               ACADEMIC HIGH SCHOOL       26068  ...
# 21                    AGCY OFFICE, TRANSL HSG - ADULT        9010  ...
# 22                                     MUSEUM/GALLERY       11346  ...
# 23                                          FIREHOUSE       42176  ...
# 24  WATERFRONT PROPERTY, NO USE, NO USE-WFT (ANY A...      320800  ...
# 25  FERRY TERMINAL, WATERFRONT PROPERTY, NO USE, F...      199625  ...
# 26  WATERFRONT PROPERTY, NO USE, FINAL COMMITMNT-DISP      202275  ...
# 27  WATERFRONT PROPERTY, NO USE, FINAL COMMITMNT-DISP      169425  ...
# 28           AGCY EXECUTVE OFFICE, OFC LEASED BY EDUC       20684  ...
# 29                                               PARK       19550  ...
# 30                               ACADEMIC HIGH SCHOOL        5882  ...
# 31                               ACADEMIC HIGH SCHOOL       10989  ...
# 32                                          FIREHOUSE        4381  ...
# 33                               OTHER TRANS FACILITY          66  ...
# 34  OFFICE, AGCY OFFICE, BOROUGH OFFICE, FIELD OFF...       59391  ...
# 35                                        AGCY OFFICE       10894  ...
# 36                               AGCY EXECUTVE OFFICE       23555  ...
# 37  WATERFRONT PROPERTY, NO USE, FINAL COMMITMNT-D...      164325  ...
# 38  WATERFRONT PROPERTY, NO USE, FINAL COMMITMNT-D...      146025  ...
# 39  WATERFRONT PROPERTY, NO USE, FINAL COMMITMNT-D...      208475  ...
# 40          NO USE-NON RES STRC, FINAL COMMITMNT-DISP       21475  ...
# 41  WATERFRONT PROPERTY, NO USE-NON RES STRC, FINA...       23350  ...
# 42         NO USE-WFT (ANY AGY), FINAL COMMITMNT-DISP      404450  ...
# 43         NO USE-WFT (ANY AGY), FINAL COMMITMNT-DISP        9650  ...
# 44         NO USE-WFT (ANY AGY), FINAL COMMITMNT-DISP      147775  ...
# 45  PARK, NO USE, FINAL COMMITMNT-DISP, IN USE-TEN...       47539  ...
# 46  PARK, NO USE, FINAL COMMITMNT-DISP, IN USE-TEN...       22533  ...
# 47           AGCY EXECUTVE OFFICE, FIELD OFFICE-STAFF       32511  ...
# 48                                        AGCY OFFICE       10586  ...
# 49                       OFFICE, AGCY EXECUTVE OFFICE       30332  ...
#
#    SP Dist 1 SP Dist 2                                 Potential Urban Ag  \
# 0         LM       NaN                                                NaN
# 1         LM       NaN                                                NaN
# 2        NaN       NaN                                                NaN
# 3        NaN       NaN                                                NaN
# 4        NaN       NaN                                                NaN
# 5        NaN       NaN                                                NaN
# 6        NaN       NaN                                                NaN
# 7         LM       NaN                                                NaN
# 8        NaN       NaN                                                NaN
# 9         LM       NaN                                                NaN
# 10        LM       NaN                                                NaN
# 11        LM       NaN  Not Suitable 2 - Site is smaller than 2500 squ...
# 12        LM       NaN                                                NaN
# 13        LM       NaN                                                NaN
# 14        LM       NaN                                                NaN
# 15        LM       NaN                                                NaN
# 16        LM       NaN                                                NaN
# 17        LM       NaN                                                NaN
# 18       NaN       NaN                                                NaN
# 19        LM       NaN                                                NaN
# 20        LM       NaN                                                NaN
# 21        LM       NaN                                                NaN
# 22        LM       NaN                                                NaN
# 23        LM       NaN                                                NaN
# 24        LM       NaN                                                NaN
# 25        LM       NaN                                                NaN
# 26        LM       NaN                                                NaN
# 27        LM       NaN                                                NaN
# 28        LM       NaN                                                NaN
# 29       NaN       NaN                                                NaN
# 30        LM       NaN                                                NaN
# 31        LM       NaN                                                NaN
# 32        LM       NaN                                                NaN
# 33        LM       NaN  Not Suitable 2 - Site is smaller than 2500 squ...
# 34        LM       NaN                                                NaN
# 35        LM       NaN                                                NaN
# 36        LM       NaN                                                NaN
# 37        LM       NaN                                                NaN
# 38        LM       NaN                                                NaN
# 39        LM       NaN                                                NaN
# 40        LM       NaN                                                NaN
# 41        LM       NaN                                                NaN
# 42        LM       NaN                                                NaN
# 43        LM       NaN                                                NaN
# 44        LM       NaN                                                NaN
# 45        LM       NaN                                                NaN
# 46        LM       NaN                                                NaN
# 47        LM       NaN                                                NaN
# 48        LM       NaN                                                NaN
# 49        LM       NaN                                                NaN
#
#                                               Contact  EDC % Occupied  \
# 0   Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 1   Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 2   Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 3   Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 4   Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 5   Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 6   Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 7   Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 8   Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 9   Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 10  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 11  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 12  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 13  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 14  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 15  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 16  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 17  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 18  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 19  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 20  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 21  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 22  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 23  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 24  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 25  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 26  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 27  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 28  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 29  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 30  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 31  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 32  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 33  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 34  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 35  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 36  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 37  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 38  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 39  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 40  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 41  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 42  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 43  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 44  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 45  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 46  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 47  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 48  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
# 49  Christian Grove cgrove@dcas.nyc.gov  212 386-0613             0.0
#
#     Pluto Version   Latitude  Longitude      BIN  \
# 0            13v1        NaN        NaN      NaN
# 1            13v1  40.701481 -74.009171  1075697
# 2            13v1  40.702880 -74.015523  1000000
# 3            13v1  40.702153 -74.013146  1085598
# 4            13v1  40.702153 -74.013146  1085598
# 5            13v1  40.702198 -74.009702  1000000
# 6            13v1        NaN        NaN      NaN
# 7            13v1  40.705136 -74.017720  1085492
# 8            13v1        NaN        NaN      NaN
# 9            13v1  40.706745 -74.016021  1088913
# 10           13v1  40.706921 -74.014074  1078977
# 11           13v1  40.707047 -74.013984  1000795
# 12           13v1  40.706638 -74.012631  1000807
# 13           13v1  40.706995 -74.012335  1000808
# 14           13v1  40.706045 -74.013096  1078979
# 15           13v1  40.706270 -74.012909  1000812
# 16           13v1  40.706449 -74.012761  1000813
# 17           13v1  40.705351 -74.011502  1000817
# 18           13v1        NaN        NaN      NaN
# 19           13v1  40.703921 -74.010348  1000000
# 20           13v1  40.704487 -74.011556  1000849
# 21           13v1  40.705079 -74.010766  1000850
# 22           13v1  40.703279 -74.008039  1000866
# 23           13v1  40.703880 -74.008220  1000867
# 24           13v1        NaN        NaN      NaN
# 25           13v1  40.703587 -74.006597  1087760
# 26           13v1  40.701761 -74.011310  1000005
# 27           13v1  40.704600 -74.005143  1087761
# 28           13v1  40.707116 -74.007329  1001015
# 29           13v1        NaN        NaN      NaN
# 30           13v1  40.708686 -74.012361  1001035
# 31           13v1  40.709040 -74.012127  1001037
# 32           13v1  40.709773 -74.012801  1075700
# 33           13v1        NaN        NaN      NaN
# 34           13v1  40.708933 -74.007614  1079043
# 35           13v1  40.707443 -74.007607  1001111
# 36           13v1  40.706787 -74.005114  1001134
# 37           13v1        NaN        NaN      NaN
# 38           13v1        NaN        NaN      NaN
# 39           13v1  40.706310 -74.003041  1001158
# 40           13v1  40.706310 -74.003041  1001159
# 41           13v1        NaN        NaN      NaN
# 42           13v1        NaN        NaN  1000000
# 43           13v1        NaN        NaN      NaN
# 44           13v1        NaN        NaN      NaN
# 45           13v1  40.705865 -74.003769  1085797
# 46           13v1  40.706310 -74.003235  1082003
# 47           13v1  40.708791 -74.007189  1001186
# 48           13v1  40.710059 -74.005955  1001269
# 49           13v1  40.709202 -74.005710  1001280
#
#                                                   NTA
# 0                                                 NaN
# 1   Battery Park City-Lower Manhattan             ...
# 2   park-cemetery-etc-Manhattan                   ...
# 3   Battery Park City-Lower Manhattan             ...
# 4   Battery Park City-Lower Manhattan             ...
# 5   Battery Park City-Lower Manhattan             ...
# 6                                                 NaN
# 7   Battery Park City-Lower Manhattan             ...
# 8                                                 NaN
# 9   Battery Park City-Lower Manhattan             ...
# 10  Battery Park City-Lower Manhattan             ...
# 11  Battery Park City-Lower Manhattan             ...
# 12  Battery Park City-Lower Manhattan             ...
# 13  Battery Park City-Lower Manhattan             ...
# 14  Battery Park City-Lower Manhattan             ...
# 15  Battery Park City-Lower Manhattan             ...
# 16  Battery Park City-Lower Manhattan             ...
# 17  Battery Park City-Lower Manhattan             ...
# 18                                                NaN
# 19  Battery Park City-Lower Manhattan             ...
# 20  Battery Park City-Lower Manhattan             ...
# 21  Battery Park City-Lower Manhattan             ...
# 22  Battery Park City-Lower Manhattan             ...
# 23  Battery Park City-Lower Manhattan             ...
# 24                                                NaN
# 25  Battery Park City-Lower Manhattan             ...
# 26  Battery Park City-Lower Manhattan             ...
# 27  Battery Park City-Lower Manhattan             ...
# 28  Battery Park City-Lower Manhattan             ...
# 29                                                NaN
# 30  Battery Park City-Lower Manhattan             ...
# 31  Battery Park City-Lower Manhattan             ...
# 32  Battery Park City-Lower Manhattan             ...
# 33                                                NaN
# 34  Battery Park City-Lower Manhattan             ...
# 35  Battery Park City-Lower Manhattan             ...
# 36  Battery Park City-Lower Manhattan             ...
# 37                                                NaN
# 38                                                NaN
# 39  Battery Park City-Lower Manhattan             ...
# 40  Battery Park City-Lower Manhattan             ...
# 41                                                NaN
# 42                                                ...
# 43                                                NaN
# 44                                                NaN
# 45  Battery Park City-Lower Manhattan             ...
# 46  Battery Park City-Lower Manhattan             ...
# 47  Battery Park City-Lower Manhattan             ...
# 48  Battery Park City-Lower Manhattan             ...
# 49  Battery Park City-Lower Manhattan             ...
#
# [50 rows x 74 columns]

# %%
rename_dict = {"Borough": "", 
       "Map Atlas": "map_atlas", 
       "Block": "block", 
       "Lot": "lot", 
       "Address": "address", 
       "Parcel Name": "parcel_name", 
       "Agency": "agency", 
       "Current Uses": "current_uses",
       "Total Area": "total_area", 
       "Open Petroleum Spill": "open_petroleum_spill", 
       "Govt Clean-Up Program": "govt_clean-up_program", 
       "Structure Completed": "stucture_completed",
       "Number Structures": "number_structures", 
       "Total Gross Area Structures": "total_gross_area_structures", 
       "Ratio Building to Floor Area": "ratio_building_to_floor_area",
       "Allowable Building to Floor": "allowable_building_to_floor", 
       "Land Use Category": "land_use_category", 
       "Community Board": "community_board", 
       "Census Tract": "census_tract",
       "Census Block": "census_block", 
       "School Dist": "school_district", 
       "Council District": "council_district",
       "Postcode": "post_code", 
       "Fire Comp": "fire_comp", 
       "Health Area": "health_area",
       "Health Ctr": "health_ctr", 
       "Police Prct": "police_prct", 
       "Major Use": "major_use", 
       "Number of Easements": "number_of_elements", 
       "Commercial Floor Area": "commercial_floor_area",
       "Residential Floor Area": "residential_floor_area", 
       "Office Floor Area": "office_floor_area", 
       "Retail Floor Area": "retail_floor_area", 
       "Garage Floor Area": "garage_floor_area",
       "Storage Floor Area": "storage_floor_area", 
       "Factory Floor Area": "factory_floor_area", 
       "Other Floor Area" "other_floor_area", 
       "Num Floors": "nu _floors",
       "Residential Units": "residential_units", 
       "Residential and Non-Residential Units": "residential_and_non-residential_units", 
       "Lot Front": "lot_front",
       "Lot Depth": "lot_depth",
       "Bldg Front": "bldg_front", 
       "Bldg Depth": "bldg_depth", 
       "Proximity Code": "proximity_code", 
       "Irr Lot Code": "irr_lot_code", 
       "Lot Type Code": "lot_type_code", 
       "Bsmt Code": "bsmt_code",
       "Assess Land": "assess_land", 
       "Exempt Land": "exempt_land", 
       "Exempt Tot": "exempt_tot", 
       "Year Alter 1": "year_alter_1", 
       "Year Alter 2": "year_alter_2", 
       "His Dist": "his_dist",
       "Landmark": "landmark", 
       "Condominium Number": "condominium_number", 
       "Coordinates": "coordinated", 
       "E-Designation Number": "e-designation_number", 
       "Industrial Business Zone": "industrial_business_zone",
       "Zone Dist": "zone_dist", 
       "Zone Dist 2": "zone_dist_2", 
       "Overlay 1": "overlay_1", 
       "Overlay 2": "overlay_2", 
       "SP Dist 1": "sp_dist_1", 
       "SP Dist 2": "sp_dist_2",
       "Potential Urban Ag": "potential_urban_ag", 
       "Contact": "contact", 
       "EDC % Occupied": "edc_percent_occupied", 
       "Pluto Version": "pluto_version", 
       "Latitude": "latitude", 
       "Longitude": "longitude",
       "BIN": "bin", 
       "NTA": "nta"}

# %% [markdown]
# ## Plot the density of missing values
#
# To do this we'll first count the number of NA's (NaN) in each column and convert that to a percentage.

# %%
nas = (nyc.isna().sum()).sort_values()
na_percent = (nas / (nas + nyc.count()) 
              * 100).sort_values()
colnames = list(nas.index)

# %% [markdown]
# Then, using matplotlib, we can create a horizontal bar chart with each column on the vertical axis, and the percentage of missing values on the horizontal axis.  For style, we'll also annotate the number of NA's (count) to the right of each horizontal bar.

# %%
# %matplotlib inline

plt.style.use('ggplot')
# This section of code was inspired by:
# https://stackoverflow.com/questions/28931224/adding-value-labels-on-a-matplotlib-bar-chart

fig = plt.figure(figsize = (15, 15))
ax = na_percent.plot(kind ='barh')
ax.set_title('Missing Value Density', fontsize = 20)
ax.set_xlabel('Percent Missing (%)', fontsize = 18)
ax.set_yticklabels(colnames)

def add_counts(ax, nas, spacing=15):
    # For each bar, place a label
    for rect, count in zip(ax.patches, nas):
        # Get X and Y placement of label from rect.
        x_value = rect.get_width()
        y_value = rect.get_y() 
        - rect.get_height() / 2    # This makes the text appear in the middle of the bar

        space = spacing  # Distance to the right the annotation appears
        label = count

        # Create the annotation
        ax.annotate(label, 
                    (x_value, y_value), 
                    xytext=(space, 0), 
                    textcoords = "offset points", 
                    ha = 'center', 
                    va = 'bottom')

# Add the counts
add_counts(ax, nas)
# Add a verticle line at 90%
ax.axvline(x = 90, color = "red", alpha = .5)

# %% [markdown]
# ### Analysis of missing values
#
# The verticle line at 90% was added to highlight where nearly all of the data for a given column is missing.  We see that the following features exceed this threshold:
#
# - SP Dist 2
# - Overlay 2
# - Govt Clean-Up Program
# - His Dist
# - Landmark
# - E-Designation Number
# - Open Petroleum Spill
# - Industrial Business Zone
# - Zone Dist 2
#
# These represent features that need to be scruitinized very carefully to determine whether or not they add anything meaningful to any future analysis.  If they are deemed unnecessary, they should be removed from the data set in order to reduce the number of features under analysis and help mitigate the curse of dimensionality.  The alternative is that these features represent some important aspect and may be the key to uncovering some valuable information.  Let us next explore in greater detail what each of these features are to determine their usefulness.

# %% [markdown]
# #### SP Dist 2
#
# Special districts respond to specific conditions; each special district designated by the Commission stipulates zoning requirements and/or zoning incentives tailored to distinctive qualities that may not lend themselves to generalized zoning and standard development.
#
# https://www1.nyc.gov/site/planning/zoning/districts-tools/special-purpose-districts.page
#
# Since SP Dist 2 is a code for a property with a second special district, this information may be unnecessary.

# %% [markdown]
# #### Overlay 2
#
# Commercial activities in the city are permitted in eight commercial districts based on their functional similarities and locational requirements. Small retail and service shops in C1 and C2 districts serve the immediate needs of surrounding residential communities. Larger stores with more goods and services are found in C4 districts, borough-wide regional retail centers like Main Street in Flushing and Fordham Road in the Bronx. C5 and C6 districts, central business districts that serve the city, the region and the nation, are mapped in Midtown, Lower Manhattan, Downtown Brooklyn and Long Island City. Three districts serve specific purposes: C3 for waterfront recreation, C7 for amusement parks and C8 for heavy repair shops and automotive uses.
#
# https://www1.nyc.gov/site/planning/zoning/districts-tools/commercial-districts-c1-c8.page
#
# Since Overlay 2 is a code for a property with a second commercial district, this information may be unnecessary.

# %% [markdown]
# #### Govt Clean-Up Program
#
# The New York City Voluntary Cleanup Program (VCP) is a voluntary environmental remediation program administered by the New York City Office of Environmental Remediation (OER). It was established to ensure that any vacant property in NYC with light to moderate levels of contamination can be cleaned up to New York State standards with government support to protect public health and the environment and redeveloped in a timely manner.
#
# http://home2.nyc.gov/html/oer/html/voluntary-cleanup-program/vcp.shtml
#
# This could be an important feature and should be included in initial analyses.

# %% [markdown]
# #### His Dist
#
# Administered by the National Park Service, the National Register of Historic Places was created in 1966 as the official federal list of districts, sites, buildings, structures, and objects significant in American history, architecture, archeology, engineering, and culture. The State and National Preservation Commissions both recognize buildings and areas as having historic merit.
#
# This designation is considered largely honorific and does not create mandatory historic districts where no buildings can be altered. Property owners can still do what they want to their property within these districts. But there are benefits available in the form of significant financial incentives like tax credits and grants for preservation of these properties for homeowners as well as businesses. The incentives have been used to help turn old factories into residential buildings, for example, as well as in revitalizing historic downtowns.
#
# https://www.6sqft.com/historic-districts-and-landmarking-what-they-mean-and-how-they-could-affect-you/
#
# This could be an important feature and should be included in initial analyses.

# %% [markdown]
# #### Landmark
#
# The Landmarks Preservation Commission is a charter-mandated New York City commission. The Commission was created in 1965 through groundbreaking legislation signed by the late Mayor Robert F. Wagner in response to the losses of historically significant buildings in New York City, most notably, Pennsylvania Station.
#
# According to the Landmarks Law, the purpose of safeguarding the buildings and places that represent New York City's cultural, social, economic, political, and architectural history is to:
#
# - Stabilize and improve property values
# - Foster civic pride
# - Protect and enhance the City's attractions to tourists
# - Strengthen the economy of the City
# - Promote the use of historic districts, landmarks, interior landmarks, and scenic landmarks for the education, pleasure and welfare of the people of the City
#
# https://www1.nyc.gov/site/lpc/about/about-lpc.page
#
# This could be an important feature and should be included in initial analyses.

# %% [markdown]
# #### E-Designation Number
#
# A property with an E-designation means that, as a consequence of a zoning action, a property has environmental requirements relating to air, noise or hazardous materials that must be investigated and addressed before an owner can obtain a building permit for the property's redevelopment.
#
# OER manages three E-designations:
#
# - Hazardous materials: This will require soil testing, and if contamination is confirmed, a remedial action plan must be approved by OER before development can proceed, and the plan must be implemented to the satisfaction of OER before occupancy is allowed.
# - Noise: This will require the installation of a specific window/wall attenuation and alternate means of ventilation. A remedial action plan must be approved by OER before development can proceed, and the plan must be implemented to the satisfaction of OER before occupancy is allowed.
# - Air: This requirement may limit the boiler fuel to natural gas or specify location of the boiler stack. A remedial action plan must be approved by OER before development can proceed, and the plan must be implemented to the satisfaction of OER before occupancy is allowed.
#
# https://www1.nyc.gov/site/oer/remediation/e-designation.page
#
# This could be an important feature and should be included in initial analyses.

# %% [markdown]
# #### Open Petroleum Spill
#
# New York State (NYS) responds to reports of petroleum and other hazardous material releases through the Spill Response Program maintained by the NYS Department of Environmental Conservation (DEC). Spill response staff throughout the State investigate such spill reports and take action based on the type of material spilled, the potential environmental damage, and safety risks to the public.
#
# Both immediate response and continued cleanup vary depending on the type of material spilled and the damage caused. Federal and State law require the spiller, or responsible party, to notify government agencies and to contain, clean up, and dispose of any spilled/contaminated material in order to correct any environmental damage.
#
# https://www.dec.ny.gov/chemical/8428.html
#
# This could be an important feature and should be included in initial analyses.

# %% [markdown]
# #### Industrial Business Zone
#
# In early 2006, the City created sixteen Industrial Business Zones across the City where expanded business services are available for industrial and manufacturing businesses. This designation fosters high-performing business districts by creating competitive advantages over locating in areas outside of New York City. The IBZs are supported by tax credits for relocating within them, zone-specific planning efforts, and direct business assistance from Industrial Providers of NYC Business Solutions Industrial and Transportation. In light of the purpose of IBZs to foster industrial sector growth by creating real estate certainty, the previous administration stated that it would not support the rezoning of these areas for residential use.
#
# https://www.nycedc.com/industry/industrial/nyc-industrial-business-zones
#
# This could be an important feature and should be included in initial analyses.

# %% [markdown]
# #### Zone Dist 2
#
# The current Zoning Resolution was adopted on December 15, 1961 to apply citywide. When changing conditions warrant them, periodic updates and amendments are made to maintain a rational use of land. Each plot of land within the City’s jurisdiction has a zoning designation — residence, commercial, or manufacturing—to establish relevant parameters for building and land use. Numerous zoning districts are mapped in the City’s diverse neighborhoods to preserve their varying density and character. These limits help give shape to neighborhoods and predictability to their future. The City continues to adapt the Zoning Resolution as the land use patterns in the City change through private and public actions.
#
# https://www1.nyc.gov/site/planning/zoning/about-zoning.page
#
# Other types of combinations are often caused when a property crosses a zoning district boundary. Special regulations in PDF Document Article VII, Chapter 7 explain how to determine what height, setback, floor area, and use regulations apply to your property.
#
# https://www1.nyc.gov/site/planning/zoning/zoning-faq.page
#
# Since Zone Dist 2 is a code for a property with a second zoning district, this information may be unnecessary.

# %% [markdown]
# ### Interpolating missing values
#
# Upon further investigation, some features with missing values may be interpolated without consequence.  One such example is the Building Identification Number (BIN).  According to https://nycplanning.github.io/Geosupport-UPG/chapters/chapterVI/section03/, missing BINs should be recorded by their borough number followed by 6 zeros.

# %% [markdown]
# #### Generate missing BINs
#
# To remedy this situation, for every missing BIN we can multiply its Borough number by 1,000,000 to generate the correct BIN for that property.  The Missing Value Density plot reveals that the Borough feature has no missing values, so we will convert the Borough value from a catagorical factor to an integer before multiplying by 1,000,000.

# %%
# Identify the indices of missing BINs

# Multiply Borough (as an integer) by 1,000,000 at the identified indices and assign it BIN
nyc.loc[nyc.BIN.isna() , "BIN"] = 1000000 * nyc.loc[nyc.BIN.isna(), "Borough"].astype(int)

# %% [markdown]
# ## Separating the "Current Uses" column
#
# The "Current Uses" column is interesting in that it lists the known uses for each building, and would be a good metric to predict or cluster.  What makes it interesting though is how the uses are listed in the data set.  For most records, different uses are separated by a comma and a space.  However, there are several instances where uses are separated by a semicolon, and others still that are separated by a semicolon and a space.  We will need consistency to make use of this feature.
#
# To accomplish this, we will replace the semicolon (and the semicolon with a space) with a comma and a space.  Then, each different use can be identified by splitting the entry at each comma and space.

# %%
# -------- I don't know how to format this to PEP 8----------

# Replace the ";"s and "; "s with ", " everywhere data exists,
# then split by ", "s.
#print(nyc.loc[nyc["Current Uses"].isna(), "Current Uses"])
nyc.loc[nyc["Current Uses"].notna(), "Current Uses"] = nyc.loc[nyc["Current Uses"].notna(), "Current Uses"].str.replace("; ; ", ", ").str.replace("; ", ", ").str.replace(";", ", ").str.split(", ")

# %% [markdown]
# ### Create a new feature based on unique "Current Uses" values
#
# Now that the "Current Uses" are stored as a list for each record, we should identify how many unique values there are and if any are similar enough to merit being grouped into a single entity.
#
# But first, we must address the missing values in this column.  Where there is a missing value, we will replace it with a "NO DATA"

# %%
# Replace missing values with "NO DATA"
nyc.loc[nyc["Current Uses"].isna(), "Current Uses"] = ["NO DATA"]

# Identify every unique "Current Use"
unique_uses = []
for id, record in enumerate(nyc["Current Uses"]):
    if record != "NO DATA":
        for use in record:
            if use not in unique_uses:
                unique_uses.append(use)
                print(id, use)

unique_uses.sort()
del(unique_uses[0])  # The first value is ''.  Remove that.
# Out:
# 0 FERRY TERMINAL
# 0 WATERFRONT PROPERTY
# 0 NO USE
# 1 FINAL COMMITMNT-DISP
# 1 IN USE-TENANTED
# 1 LONG-TERM AGREEMENT
# 2 PARK
# 8 SHORT-TERM AGREEMENT
# 9 GARAGE
# 10 OTHER TRANS FACILITY
# 12 AGCY OFFICE
# 14 AGCY EXECUTVE OFFICE
# 16 PUBLIC SCHOOL
# 17 OFFICE
# 17 BOROUGH OFFICE
# 19 ROAD/HIGHWAY
# 20 ACADEMIC HIGH SCHOOL
# 21 TRANSL HSG - ADULT
# 22 MUSEUM/GALLERY
# 23 FIREHOUSE
# 24 NO USE-WFT (ANY AGY)
# 28 OFC LEASED BY EDUC
# 34 FIELD OFFICE-PUBLIC
# 40 NO USE-NON RES STRC
# 47 FIELD OFFICE-STAFF
# 52 NO USE-VACANT LAND
# 54 SENIOR CENTER
# 54 CUSTODIAL
# 55 TRANSIT SUBSTATION
# 56 PUBLIC PLACE/PLAZA
# 61 TRANSIT WAY
# 65 OUTDOOR STRG-EQUIP
# 66 TRANSL HSG - FAMILY
# 67 ELEMENTARY SCHOOL
# 68 PLAYING FIELD
# 84 OPEN SPACE
# 86 COMMUNITY PARK
# 87 COURTHOUSE
# 88 COMMUNITY GARDEN
# 89 TRAIN FAC-INDOOR
# 92 RETAIL
# 97 INDOOR STORAGE-EQUIP
# 97 TESTING FACILITY
# 97 S/T & L/T AGREEMENTS
# 104 CRIMINAL JUSTICE FAC
# 104 MISCELLANEOUS USE
# 107 MUNICPL PKNG-OUTDOOR
# 112 INDOOR STORAGE(WHSE)
# 114 PUB SAFETY FACILITY
# 115 SECTION STATION
# 120 JAIL
# 123 POLICE STATION
# 126 WASTEWATER PUMPING
# 131 AMBULANCE STATION
# 131 COMBINED MAINT/STRG
# 136 PLAYGROUND
# 138 PLAYGRND/SPORTS AREA
# 153 INTERMEDIATE SCHOOL
# 154 HEALTH FACILITY
# 156 INDOOR MAINT/STORAGE
# 156 MAINTENANCE
# 164 BRANCH LIBRARY
# 207 NO USE-RES STRUCTURE
# 209 RECREATIONL FACILITY
# 213 IN USE-RES STRUCTURE
# 216 DAY CARE CENTER
# 220 CULTURAL FACILITY
# 233 TRANSL HSG - WOMEN
# 241 NEIGHBORHOOD PARK
# 279 OUTDR PKNG-EMPLOYEES
# 321 NATURAL AREA/ETC
# 332 OTHER PUB SAFETY FAC
# 332 MUNICIPL PKNG-INDOOR
# 337 ALTERNTV HIGH SCHOOL
# 341 EDUCATIONAL FACILITY
# 347 OTHER CULTURAL FAC
# 349 OTHER SCHOOL
# 356 SPECIAL EDUC SCHOOL
# 356 OUTDOOR PKNG-AGENCY
# 371 EARLY CHILDHD CENTER
# 374 VOCATION HIGH SCHOOL
# 394 THEATER
# 394 OTHER SPC REC-INDOOR
# 397 OTH WATER SUPPLY FAC
# 411 HIGHWAY STRIP/ETC
# 431 RAIL LINE
# 436 VEHICLE MAINTENANCE
# 439 OUTDOOR PARKING
# 462 AMBUL HEALTH FACIL
# 484 OTHER COLLEGE/UNIV
# 513 ANTENNA
# 553 OTH OUTDOOR STORAGE
# 555 HOSPITAL
# 555 OTH DETENTION FACIL
# 555 TESTING LABORATORY
# 578 FINAL COMMITMENT
# 614 INDOOR STRG-SUPPLIES
# 628 OTH WATER TRANS FAC
# 631 SOLID WASTE TSFR STN
# 632 RESERVOIR
# 638 SPECIALIZED LIBRARY
# 645 RECREATION CTR/GYM
# 685 MAIN LIBRARY
# 685 PUMPING STATION
# 708 SPEC RECREATN-INDOOR
# 735 OTHR SPC REC-OUTDOOR
# 737 RES HEALTH CARE FAC
# 895 ACCESSORY PLAY AREA
# 916 OTHER HEALTH FACILTY
# 940 OTHER POLL CNTRL FAC
# 984 SOCIAL SERVICE FACIL
# 1079 OUTDOOR STORAGE
# 1118 COMMUNITY CENTER
# 1215 OTHER OPEN SPACE
# 1257 EDUC SKILLS CENTER
# 1396 TRANSIT YARD
# 1451 AQUEDUCT
# 1481 WATER POLL CNTRL PLT
# 1490 MATERIAL PROCESS FAC
# 1542 TRAIN FACIL-OUTDOOR
# 1602 OUTDOOR TOW POUND
# 1603 OUTDOOR MAINT/STORGE
# 1606 OTH INDOOR MAINT/STG
# 1610 TRANS/PUBLIC PARKING
# 1616 OUTDOOR STORAGE-BULK
# 1668 OTH SECURE DETENTION
# 1713 SITTING AREA
# 1738 UNDEVELOP OPEN SPACE
# 1750 STADIUM
# 1762 COURT (SPORTS)
# 1983 FACILITIES MAINT
# 2197 CHARTER SCHOOL
# 2277 SPECIAL REC-OUTDOOR
# 2281 POLLUTION CONTRL FAC
# 2289 SLUDGE DE-WATERING
# 2291 COMMERCIAL MARKET
# 2460 OTH OUTDR MAINT/STG
# 2661 ZOO/AQUARIUM
# 2812 WATER SUPPLY FACIL
# 2829 NEIGHBORHD SIT AREA
# 2830 BOTANICAL GARDEN
# 2854 MARINA
# 2878 EMERGENCY MEDICL STN
# 3459 REGIONAL PARK
# 3499 PIER - MARITIME USE
# 3657 SENIOR COLLEGE
# 3660 TELE/COMP FACILITY
# 3669 TRAINING FACILITY
# 3969 ASPHALT PLANT
# 3996 PIER - NO USE
# 4006 OTHER RAIL FACILITY
# 4526 TRANSIT FACILITY
# 4628 TRANSL HSG - MEN
# 4851 OTHER MAINTENANCE
# 5213 OTHER TESTING FACIL
# 5265 SOLID WASTE FACILITY
# 5269 O/D STRG-AGY VEHICLE
# 5332 OTHER REC FACILITY
# 5622 OUTDOOR PKNG-CLIENTS
# 6780 BEACH
# 6813 FIELD OFFICE
# 7102 BUS STATION
# 7319 INDOOR STORAGE-BULK
# 7392 AIRPORT
# 7557 OUTDOOR POOL
# 7734 STORMWATER PUMPING
# 7997 INDOOR STRG-PRINTED
# 8375 GOLF COURSE
# 8786 RES FACIL - CHILDREN
# 8802 NON-RES SOC SERV FAC
# 8885 CEMETERY
# 10395 SOLID WASTE LANDFILL
# 15490 AIR RIGHTS
# 17984 COMMUNITY COLLEGE
# 20514 LIBRARY
# 27658 OTH SOCIAL SERV FAC
# 28325
# 30404 OTH COMMERCIAL MKT
# 31251 OTHR PLAY/SPORT AREA
# 31853 WHOLESALE FOOD MKT
# 42474 S/T &amp
# 42474 L/T AGREEMENTS
# 43508 RESIDENTIAL
# 44549 OTHER TRANSL HOUSING
# 52768 MUNICIPAL PARKING

# %% [markdown]
# ### Visualize the frequency of uses
#
# We have the various uses for each building.  Now let's see what the distribution looks like.

# %%
uses = pd.DataFrame({"Counts": np.zeros(len(unique_uses))}, index = [unique_uses])
for record in nyc["Current Uses"]:
    if record != "NO DATA":
        for use in record:
            uses.loc[use, "Counts"] += 1
print(uses)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\andrew\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-271-2184fdb22245> in <module>
#       3     if record != "NO DATA" and record != '':
#       4         for use in record:
# ----> 5             uses.loc[use, "Counts"] += 1
#       6 print(uses)
#
# c:\users\andrew\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1492             except (KeyError, IndexError, AttributeError):
#    1493                 pass
# -> 1494             return self._getitem_tuple(key)
#    1495         else:
#    1496             # we by definition only have the 0th axis
#
# c:\users\andrew\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     866     def _getitem_tuple(self, tup):
#     867         try:
# --> 868             return self._getitem_lowerdim(tup)
#     869         except IndexingError:
#     870             pass
#
# c:\users\andrew\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     986         for i, key in enumerate(tup):
#     987             if is_label_like(key) or isinstance(key, tuple):
# --> 988                 section = self._getitem_axis(key, axis=i)
#     989
#     990                 # we have yielded a scalar ?
#
# c:\users\andrew\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1911         # fall thru to straight lookup
#    1912         self._validate_key(key, axis)
# -> 1913         return self._get_label(key, axis=axis)
#    1914
#    1915
#
# c:\users\andrew\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     139             raise IndexingError('no slices here, handle elsewhere')
#     140
# --> 141         return self.obj._xs(label, axis=axis)
#     142
#     143     def _get_loc(self, key, axis=None):
#
# c:\users\andrew\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3581         if isinstance(index, MultiIndex):
#    3582             loc, new_index = self.index.get_loc_level(key,
# -> 3583                                                       drop_level=drop_level)
#    3584         else:
#    3585             loc = self.index.get_loc(key)
#
# c:\users\andrew\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\multi.py in get_loc_level(self, key, level, drop_level)
#    2569                 return indexer, maybe_droplevels(indexer, ilevels, drop_level)
#    2570         else:
# -> 2571             indexer = self._get_level_indexer(key, level=level)
#    2572             return indexer, maybe_droplevels(indexer, [level], drop_level)
#    2573
#
# c:\users\andrew\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\multi.py in _get_level_indexer(self, key, level, indexer)
#    2650         else:
#    2651
# -> 2652             code = level_index.get_loc(key)
#    2653
#    2654             if level > 0 or self.lexsort_depth == 0:
#
# c:\users\andrew\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
# -> 2658                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2659         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2660         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''

# %%
# Out:
# ['AGCY EXECUTVE OFFICE',
#  'TESTING FACILITY',
#  'INDOOR STORAGE-EQUIP',
#  'BOROUGH OFFICE',
#  '',
#  'AGCY OFFICE']

# %%
# Out:
# ['Date Created',
#  'Borough',
#  'Map Atlas',
#  'Block',
#  'Lot',
#  'Address',
#  'Parcel Name',
#  'Agency',
#  'Current Uses',
#  'Total Area',
#  'Open Petroleum Spill',
#  'Govt Clean-Up Program',
#  'Structure Completed',
#  'Number Structures',
#  'Total Gross Area Structures',
#  'Ratio Building to Floor Area',
#  'Allowable Building to Floor Area',
#  'Land Use Category',
#  'Community Board',
#  'Census Tract',
#  'Census Block',
#  'School Dist',
#  'Council District',
#  'Postcode',
#  'Fire Comp',
#  'Health Area',
#  'Health Ctr',
#  'Police Prct',
#  'Major Use',
#  'Number of Easements',
#  'Commercial Floor Area',
#  'Residential Floor Area',
#  'Office Floor Area',
#  'Retail Floor Area',
#  'Garage Floor Area',
#  'Storage Floor Area',
#  'Factory Floor Area',
#  'Other Floor Area',
#  'Num Floors',
#  'Residential Units',
#  'Residential and Non-Residential Units',
#  'Lot Front',
#  'Lot Depth',
#  'Bldg Front',
#  'Bldg Depth',
#  'Proximity Code',
#  'Irr Lot Code',
#  'Lot Type Code',
#  'Bsmt Code',
#  'Assess Land',
#  'Exempt Land',
#  'Exempt Tot',
#  'Year Alter 1',
#  'Year Alter 2',
#  'His Dist',
#  'Landmark',
#  'Condominium Number',
#  'Coordinates',
#  'E-Designation Number',
#  'Industrial Business Zone',
#  'Zone Dist 1',
#  'Zone Dist 2',
#  'Overlay 1',
#  'Overlay 2',
#  'SP Dist 1',
#  'SP Dist 2',
#  'Potential Urban Ag',
#  'Contact',
#  'EDC % Occupied',
#  'Pluto Version',
#  'Latitude',
#  'Longitude',
#  'BIN',
#  'NTA']
